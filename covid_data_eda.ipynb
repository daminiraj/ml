# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Damini.gupta\AppData\Local\Temp\ipykernel_18964\3757845704.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
mental_health=pd.read_csv("Mental Health in Pregnancy During Covid-  19 - Mental Health in Pregnancy During Covid-  19.csv.csv")

# %%
mental_health.shape
# Out:
# (10772, 16)

# %%
mental_health
# Out:
#        OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 0           1          38.3           $200,000+        Masters degree
# 1           2          34.6           $200,000+  Undergraduate degree
# 2           3          34.3  $100,000 -$124,999  Undergraduate degree
# 3           4          28.8  $100,000 -$124,999        Masters degree
# 4           5          36.5     $40,000-$69,999  Undergraduate degree
# ...       ...           ...                 ...                   ...
# 10767   10768          38.3  $100,000 -$124,999  Undergraduate degree
# 10768   10769          29.9  $125,000- $149,999  Undergraduate degree
# 10769   10770          27.7    $20,000- $39,999  College/trade school
# 10770   10771          23.0    $20,000- $39,999  College/trade school
# 10771   10772          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# ...

# %%
mental_health.columns
# Out:
# Index(['OSF_ID', 'Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Language',
#        'Threaten_Life', 'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
mental_health.isnull().sum()/data.shape[0]*100
# Out:
# OSF_ID                                         0.000000
# Maternal_Age                                   1.030449
# Household_Income                               2.330115
# Maternal_Education                             1.643149
# Edinburgh_Postnatal_Depression_Scale          10.898626
# PROMIS_Anxiety                                11.195693
# Gestational_Age_At_Birth                      37.486075
# Delivery_Date(converted to month and year)    37.495358
# Birth_Length                                  49.127367
# Birth_Weight                                  43.575938
# Delivery_Mode                                 48.598218
# NICU_Stay                                     48.626068
# Language                                       0.000000
# Threaten_Life                                  8.317861
# Threaten_Baby_Danger                           8.392128
# Threaten_Baby_Harm                             8.280728
# dtype: float64

# %%
df1= mental_health.copy()

# %%
mental_health.drop(columns=['Language','OSF_ID'],inplace=True)

# %%
mental_health.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
mental_health
# Out:
#        Maternal_Age    Household_Income    Maternal_Education  \
# 0              38.3           $200,000+        Masters degree
# 1              34.6           $200,000+  Undergraduate degree
# 2              34.3  $100,000 -$124,999  Undergraduate degree
# 3              28.8  $100,000 -$124,999        Masters degree
# 4              36.5     $40,000-$69,999  Undergraduate degree
# ...             ...                 ...                   ...
# 10767          38.3  $100,000 -$124,999  Undergraduate degree
# 10768          29.9  $125,000- $149,999  Undergraduate degree
# 10769          27.7    $20,000- $39,999  College/trade school
# 10770          23.0    $20,000- $39,999  College/trade school
# 10771          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
mental_health.isnull().sum()
# Out:
# Maternal_Age                                   111
# Household_Income                               251
# Maternal_Education                             177
# Edinburgh_Postnatal_Depression_Scale          1174
# PROMIS_Anxiety                                1206
# Gestational_Age_At_Birth                      4038
# Delivery_Date(converted to month and year)    4039
# Birth_Length                                  5292
# Birth_Weight                                  4694
# Delivery_Mode                                 5235
# NICU_Stay                                     5238
# Threaten_Life                                  896
# Threaten_Baby_Danger                           904
# Threaten_Baby_Harm                             892
# dtype: int64

# %%
mental_health[(mental_health['PROMIS_Anxiety'].isnull())&(mental_health['Delivery_Date(converted to month and year)'].isnull())&(mental_health['Threaten_Life'].isnull())&
(mental_health['Threaten_Baby_Danger'].isnull())&(mental_health['Threaten_Baby_Harm'].isnull())]
# Out:
#        Maternal_Age    Household_Income    Maternal_Education  \
# 2              34.3  $100,000 -$124,999  Undergraduate degree
# 12             29.7  $125,000- $149,999  Undergraduate degree
# 26             33.1  $100,000 -$124,999  Undergraduate degree
# 77             24.1     $70,000-$99,999   High school diploma
# 151            38.8     $70,000-$99,999  Undergraduate degree
# ...             ...                 ...                   ...
# 10709          27.6     $70,000-$99,999  Undergraduate degree
# 10738           NaN     $70,000-$99,999  Undergraduate degree
# 10760          29.6  $100,000 -$124,999  College/trade school
# 10762          27.1     $70,000-$99,999  College/trade school
# 10768          29.9  $125,000- $149,999  Undergraduate degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 2                                       NaN             NaN
# 12                                      NaN             NaN
# ...

# %%
#rows to drop
rows_to_drop=mental_health[(mental_health['PROMIS_Anxiety'].isnull())&(mental_health['Delivery_Date(converted to month and year)'].isnull())&(mental_health['Threaten_Life'].isnull())&
(mental_health['Threaten_Baby_Danger'].isnull())&(mental_health['Threaten_Baby_Harm'].isnull())].index

# %%
mental_health.drop(rows_to_drop,inplace=True)

# %%
mental_health
# Out:
#        Maternal_Age     Household_Income    Maternal_Education  \
# 0              38.3            $200,000+        Masters degree
# 1              34.6            $200,000+  Undergraduate degree
# 3              28.8   $100,000 -$124,999        Masters degree
# 4              36.5      $40,000-$69,999  Undergraduate degree
# 5              38.3  $150,000 - $174,999  Undergraduate degree
# ...             ...                  ...                   ...
# 10766          32.7      $70,000-$99,999   High school diploma
# 10767          38.3   $100,000 -$124,999  Undergraduate degree
# 10769          27.7     $20,000- $39,999  College/trade school
# 10770          23.0     $20,000- $39,999  College/trade school
# 10771          34.6      $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
mental_health.isnull().sum()/mental_health.shape[0]*100
# Out:
# Maternal_Age                                   0.864749
# Household_Income                               2.176448
# Maternal_Education                             1.486592
# Edinburgh_Postnatal_Depression_Scale           6.743101
# PROMIS_Anxiety                                 7.054023
# Gestational_Age_At_Birth                      34.570540
# Delivery_Date(converted to month and year)    34.580257
# Birth_Length                                  46.754761
# Birth_Weight                                  40.944423
# Delivery_Mode                                 46.200933
# NICU_Stay                                     46.230082
# Threaten_Life                                  4.041974
# Threaten_Baby_Danger                           4.119705
# Threaten_Baby_Harm                             4.003109
# dtype: float64

# %%
mental_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10292 entries, 0 to 10771
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10203 non-null  float64
#  1   Household_Income                            10068 non-null  object
#  2   Maternal_Education                          10139 non-null  object
#  3   Edinburgh_Postnatal_Depression_Scale        9598 non-null   float64
#  4   PROMIS_Anxiety                              9566 non-null   float64
#  5   Gestational_Age_At_Birth                    6734 non-null   float64
#  6   Delivery_Date(converted to month and year)  6733 non-null   object
#  7   Birth_Length                                5480 non-null   float64
#  8   Birth_Weight                                6078 non-null   float64
# ...

# %%
#lets plot numerical graphs
numerical_df=mental_health.select_dtypes(include=['number'])

# %%
numerical_df
# Out:
#        Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0              38.3                                   9.0            13.0
# 1              34.6                                   4.0            17.0
# 3              28.8                                   9.0            20.0
# 4              36.5                                  14.0            20.0
# 5              38.3                                   3.0             8.0
# ...             ...                                   ...             ...
# 10766          32.7                                  15.0            27.0
# 10767          38.3                                  10.0            18.0
# 10769          27.7                                   4.0            15.0
# 10770          23.0                                  12.0            19.0
# 10771          34.6                                  18.0            30.0
#
#        Gestational_Age_At_Birth  Birth_Length  Birth_Weight  Threaten_Life  \
# ...

# %%
fig,axes =plt.subplots(3,3,figsize=(15,10))
axes =axes.flatten()
for i, col in enumerate(numerical_df.columns):
    sns.kdeplot(data=numerical_df[col],ax=axes[i])
    axes[i].set_title(col)
plt.tight_layout()
plt.show()

# %%
print(mental_health['Household_Income'].value_counts())
print(' ')
print(" ")
print(mental_health['Maternal_Education'].value_counts())
print(' ')
print(" ")
print(mental_health['Delivery_Date(converted to month and year)'].value_counts())
print(' ')
print(" ")
print(mental_health['Delivery_Mode'].value_counts())
print(' ')
print(" ")
print(mental_health['NICU_Stay'].value_counts())
# Out:
# Household_Income
# $70,000-$99,999        2006
# $100,000 -$124,999     1886
# $40,000-$69,999        1348
# $125,000- $149,999     1315
# $150,000 - $174,999    1115
# $200,000+               977
# $175,000- $199,999      641
# $20,000- $39,999        561
# Less than $20, 000      219
# Name: count, dtype: int64
#
#
# Maternal_Education
# Undergraduate degree             3979
# College/trade school             2588
# Masters degree                   1849
# High school diploma               835
# Doctoral Degree                   767
# Less than high school diploma     121
# Name: count, dtype: int64
#
#
# Delivery_Date(converted to month and year)
# Aug2020    684
# Sep2020    638
# Jul2020    630
# Oct2020    619
# Jun2020    510
# Nov2020    473
# Jan2021    413
# Dec2020    404
# Mar2021    385
# Apr2021    342
# Feb2021    315
# May2021    292
# Jun2021    281
# May2020    214
# Jul2021    208
# Aug2021    135
# Sep2021     86
# Oct2021     47
# Nov2021     21
# Apr2020     12
# ...

# %%
#bivariate analysis
mental_health.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
#converting it into months and days
mental_health['Gestational_Age_At_Birth']=np.round(Gestational_Age_At_Birth['Gestational_Age_At_Birth']/4.33,2)

# %%
mental_health['Gestational_Age_At_Birth']
# Out:
# 0        9.17
# 1         NaN
# 3        8.91
# 4        9.21
# 5        8.91
#          ...
# 10766     NaN
# 10767     NaN
# 10769     NaN
# 10770     NaN
# 10771    8.84
# Name: Gestational_Age_At_Birth, Length: 10292, dtype: float64

# %%
#create a column of healthy birth weight
def healthy_weight(row):
    if pd.isnull(row['Birth_Weight']):
        return 'Data Missing'
    elif row['Birth_Weight'] >2550 or row['Birth_Weight'] <4000:
        return 'Healthy'
    else:
        return 'Unhealthy'
        
#create a column of healthy birth length
def healthy_weight(row):
    if pd.isnull(row['Birth_Length']):
        return 'Data Missing'
    elif row['Birth_Length'] >39 or row['Birth_Length'] <61:
        return 'Healthy'
    else:
        return 'Unhealthy'

# %%
mental_health['Weight']=mental_health.apply(healthy_weight,axis=1)
mental_health['Height']=mental_health.apply(healthy_weight,axis=1)

# %%
mental_health
# Out:
#        Maternal_Age     Household_Income    Maternal_Education  \
# 0              38.3            $200,000+        Masters degree
# 1              34.6            $200,000+  Undergraduate degree
# 3              28.8   $100,000 -$124,999        Masters degree
# 4              36.5      $40,000-$69,999  Undergraduate degree
# 5              38.3  $150,000 - $174,999  Undergraduate degree
# ...             ...                  ...                   ...
# 10766          32.7      $70,000-$99,999   High school diploma
# 10767          38.3   $100,000 -$124,999  Undergraduate degree
# 10769          27.7     $20,000- $39,999  College/trade school
# 10770          23.0     $20,000- $39,999  College/trade school
# 10771          34.6      $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
#relation of maternal age with Edinburgh_Postnatal_Depression_Scale,Gestational_Age_At_Birth and PROMIS_Anxiety
fig, ax= plt.subplots(1,3,figsize=(10,10))
ax=ax.flatten()
sns.lineplot(data=mental_health,x='Maternal_Age',y='Edinburgh_Postnatal_Depression_Scale',color='red',ax=ax[0],label='maternal age vs Edinburgh_Postnatal_Depression_Scale')
sns.lineplot(data=mental_health,x='Maternal_Age',y='PROMIS_Anxiety',label='maternal age vs PROMIS_Anxiety',color='blue',ax=ax[1])
sns.lineplot(data=mental_health,x='Maternal_Age',y='Gestational_Age_At_Birth',label='maternal age vs Gestational_Age_At_Birth',color='green',ax=ax[2])


plt.show()

# %%
#relation of maternal age with Threaten_Life,Threaten_Baby_Danger and Threaten_Baby_Harm

#relation of maternal age with Edinburgh_Postnatal_Depression_Scale,Gestational_Age_At_Birth and PROMIS_Anxiety
fig, ax= plt.subplots(1,3,figsize=(10,10))
ax=ax.flatten()
sns.lineplot(data=mental_health,x='Maternal_Age',y='Threaten_Life',color='red',ax=ax[0],label='maternal age vs Threaten_Life')
sns.lineplot(data=mental_health,x='Maternal_Age',y='Threaten_Baby_Danger',label='maternal age vs Threaten_Baby_Danger',color='blue',ax=ax[1])
sns.lineplot(data=mental_health,x='Maternal_Age',y='Threaten_Baby_Harm',label='maternal age vs Threaten_Baby_Harm',color='green',ax=ax[2])


plt.show()

# %%
new_df=mental_health[mental_health['Delivery_Mode'].notnull()]

# %%
new_df=mental_health[mental_health['Maternal_Age'].notnull()]

# %%
new_df=new_df[['Maternal_Age','Delivery_Mode']]

# %%
def age_category(row):
    if row['Maternal_Age']<23:
        return 'Underage'
    elif (row['Maternal_Age']>=23 and  row['Maternal_Age']<38):
        return 'Healthy'
    elif row['Maternal_Age']>=38:
        return 'old age'

# %%
new_df['Age category']=new_df.apply(age_category,axis=1)

# %%
new_df
# Out:
#        Maternal_Age                  Delivery_Mode Age category
# 0              38.3                      Vaginally      old age
# 1              34.6                            NaN      Healthy
# 3              28.8                      Vaginally      Healthy
# 4              36.5  Caesarean-section (c-section)      Healthy
# 5              38.3                            NaN      old age
# ...             ...                            ...          ...
# 10766          32.7                            NaN      Healthy
# 10767          38.3                            NaN      old age
# 10769          27.7                            NaN      Healthy
# 10770          23.0                            NaN      Healthy
# 10771          34.6                            NaN      Healthy
#
# [10203 rows x 3 columns]

# %%
new_df.groupby('Age category')['Delivery_Mode'].value_counts()
# Out:
# Age category  Delivery_Mode
# Healthy       Vaginally                        3534
#               Caesarean-section (c-section)    1381
# Underage      Vaginally                          43
#               Caesarean-section (c-section)      16
# old age       Vaginally                         315
#               Caesarean-section (c-section)     233
# Name: count, dtype: int64

# %%
new_df.groupby('Age category')['Delivery_Mode'].value_counts().reset_index()
# Out:
#   Age category                  Delivery_Mode  count
# 0      Healthy                      Vaginally   3534
# 1      Healthy  Caesarean-section (c-section)   1381
# 2     Underage                      Vaginally     43
# 3     Underage  Caesarean-section (c-section)     16
# 4      old age                      Vaginally    315
# 5      old age  Caesarean-section (c-section)    233

# %% [markdown]
# CONCLUSION:
#
#
# If a lady is in the age group 25-38 while conceiving she will not be under any anxiety attacks , moreover she will also not suffer from any after-pregnancy depression and can take care of herself and her new born more effectively.
#
# If a female is conceiving beyond the age of 42, this is very risky for the baby as there are very high chances of pre-mature birth of the baby and the pre-mature birth may be in less than 7.5 months of gestation periods.
#
# Female of the age group 25-42 are less worried about the impact of covid-19 on them and their new born health, damang, they are less worried as compared to females who conceived in less than 25 and females conceiving in after the age 45. its also evident that female after the age of 43 are more worried about the impact of covid-19 on lady and baby , this may be reason for high anxiety and after-pregnency depression in this age group
#
# After the age of 38, there is a notable 13%[28-41%] increase in the likelihood of women requiring a c-section rather than opting for a natural delivery. this statistic underscores the physiological changes associated with maternal age and their implications for childbirth.

# %%
mental_health['Household_Income'].unique()
# Out:
# array(['$200,000+', '$100,000 -$124,999', '$40,000-$69,999',
#        '$150,000 - $174,999', nan, '$70,000-$99,999',
#        '$175,000- $199,999', '$125,000- $149,999', '$20,000- $39,999',
#        'Less than $20, 000'], dtype=object)

# %%
import plotly.express as px
categories=mental_health['Household_Income'].unique()
for i in categories:
    df= mental_health[mental_health['Household_Income']== i]
    fig= px.histogram(mental_health, x='PROMIS_Anxiety',color='Household_Income',hover_data=mental_health.columns,title='Distribution of anxiety on the basis of household income')

fig.update_layout(
    xaxis_title="PROMIS_Anxiety",
    yaxis_title="Count",
    legend_title="Household Income",
    barmode= 'overlay'   #overlay histogram fro better comparison.
)



fig.show()

# %%
import plotly.express as px

#get unique categories of income
categories = mental_health['Household_Income'].unique()

for i  in categories:
  df= mental_health[mental_health['Household_Income']==i]
  fig= px.histogram(mental_health, x='Edinburgh_Postnatal_Depression_Scale', color='Household_Income',
                   title='Distribution of EPDS by household income',
                    hover_data= mental_health.columns)


fig.update_layout(
    xaxis_title="Edinburgh_Postnatal_Depression_Scale",
    yaxis_title="Count",
    legend_title="Household Income",
    barmode= 'overlay'   #overlay histogram fro better comparison.
)

fig.show()

# %%
df=mental_health[mental_health['Threaten_Life'].notnull()]

# %%
df['Household_Income'].value_counts()
# Out:
# Household_Income
# $70,000-$99,999        1950
# $100,000 -$124,999     1841
# $40,000-$69,999        1304
# $125,000- $149,999     1283
# $150,000 - $174,999    1088
# $200,000+               957
# $175,000- $199,999      626
# $20,000- $39,999        546
# Less than $20, 000      214
# Name: count, dtype: int64

# %%
df['Threaten_Life']=df['Threaten_Life'].astype('int')

# %%
df.groupby('Household_Income')['Threaten_Life'].mean().reset_index().sort_values('Threaten_Life')
# Out:
#       Household_Income  Threaten_Life
# 5            $200,000+      39.456635
# 3   $175,000- $199,999      40.062300
# 1   $125,000- $149,999      40.482463
# 2  $150,000 - $174,999      41.392463
# 0   $100,000 -$124,999      41.783813
# 7      $70,000-$99,999      42.388205
# 6      $40,000-$69,999      45.215491
# 4     $20,000- $39,999      47.727106
# 8   Less than $20, 000      50.771028

# %%
df.groupby('Household_Income')['Threaten_Baby_Danger'].mean().reset_index().sort_values('Threaten_Baby_Danger')
# Out:
#       Household_Income  Threaten_Baby_Danger
# 5            $200,000+             46.880628
# 3   $175,000- $199,999             46.923200
# 2  $150,000 - $174,999             48.416360
# 1   $125,000- $149,999             48.924219
# 0   $100,000 -$124,999             50.265506
# 7      $70,000-$99,999             52.009259
# 6      $40,000-$69,999             53.633564
# 4     $20,000- $39,999             58.216514
# 8   Less than $20, 000             60.452830

# %%
df.groupby('Household_Income')['Threaten_Baby_Harm'].mean().reset_index().sort_values('Threaten_Baby_Harm')
# Out:
#       Household_Income  Threaten_Baby_Harm
# 2  $150,000 - $174,999           59.929228
# 5            $200,000+           60.194969
# 3   $175,000- $199,999           60.459200
# 1   $125,000- $149,999           62.057767
# 0   $100,000 -$124,999           62.330071
# 6      $40,000-$69,999           63.337442
# 7      $70,000-$99,999           63.588689
# 4     $20,000- $39,999           66.617647
# 8   Less than $20, 000           67.301887

# %%
df=df[df['Maternal_Education'].notnull()]

# %%
df.groupby('Maternal_Education')['Threaten_Life'].mean().reset_index().sort_values('Threaten_Life')
# Out:
#               Maternal_Education  Threaten_Life
# 1                Doctoral Degree      39.566088
# 4                 Masters degree      39.868071
# 5           Undergraduate degree      42.419263
# 3  Less than high school diploma      43.767241
# 0           College/trade school      44.093339
# 2            High school diploma      44.516169

# %%
df.groupby('Maternal_Education')['Threaten_Baby_Danger'].mean().reset_index().sort_values('Threaten_Baby_Danger')
# Out:
#               Maternal_Education  Threaten_Baby_Danger
# 1                Doctoral Degree             46.349800
# 4                 Masters degree             47.383805
# 5           Undergraduate degree             50.261446
# 0           College/trade school             53.802163
# 3  Less than high school diploma             55.191304
# 2            High school diploma             55.441948

# %%
df.groupby('Maternal_Education')['Threaten_Baby_Harm'].mean().reset_index().sort_values('Threaten_Baby_Harm')
# Out:
#               Maternal_Education  Threaten_Baby_Harm
# 1                Doctoral Degree           58.715241
# 4                 Masters degree           60.391570
# 5           Undergraduate degree           62.583702
# 0           College/trade school           64.026811
# 2            High school diploma           64.420922
# 3  Less than high school diploma           64.773913

# %%
df.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm', 'Weight', 'Height'],
#       dtype='object')

# %%
#relation of maternal age with Edinburgh_Postnatal_Depression_Scale,PROMIS_Anxiety and Gestational_Age_At_Birth, Bith weight

fig, ax= plt.subplots(1,3,figsize=(10,10))
ax=ax.flatten()
sns.lineplot(data=mental_health,x='Edinburgh_Postnatal_Depression_Scale',y='Gestational_Age_At_Birth',color='red',ax=ax[0])
sns.lineplot(data=mental_health,x='Edinburgh_Postnatal_Depression_Scale',y='PROMIS_Anxiety',label='maternal age vs Threaten_Baby_Danger',color='blue',ax=ax[1])
sns.lineplot(data=mental_health,x='Edinburgh_Postnatal_Depression_Scale',y='Birth_Weight',label='maternal age vs Threaten_Baby_Harm',color='green',ax=ax[2])


plt.show()

# %% [markdown]
# CONCLUSIONS
# Observational data indicates a significant correlation between high EPDS scores and the likelihood of pre-mature births. However, it's important to note that these pre-mature births generally occur after 8.5 months of gestation, which falls within the medically accepted range and thus, poses minimal health risks to the newborn.
#
# Women experiencing high levels of EPDS or anxiety are likely to experience the other condition at similar intensity levels. This linear association suggests that an increase in one condition directly correlates with an increase in the other, highlighting the intertwined nature of these mental health challenges.
